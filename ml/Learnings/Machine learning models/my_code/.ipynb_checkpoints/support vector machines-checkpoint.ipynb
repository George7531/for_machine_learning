# %% [markdown]
# # Take aways so far:
#
# * support vector classifier, just like k nearest neighbors model allow you to classify things based on their features.  support vector classifier uses a hyperplane(seperator) to divide the points. these are grouping tools.
#
# * kernals allow you to move beyond a support vector classifier and use support vector machines.
#
# * kernals are like the projecting tools that project lower dimensional support vector classifier to a higher dimensional support vector machines.
#
# * support vector machines further optimises the model and solves what the support vector classifier could not solve.
#
# * sometimes there is no place to cast the hyper plane that would seperate the points reasonably with support vector classifier, in which case we need the help of support vector machines
#
# * projecting the inseperable points in a lower dimension to a higher dimension may make it seperable with an effective hyperplane(seperator) with soft margins seperating the points and classifying them as different groups. which is done with support vector machines.
#
# # what is kernal trick?
#
# *

# %% [markdown]
# # day 73 & day 75

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sym
from IPython.display import display,Math
sym.init_printing()
import scipy.stats as stats
from PIL import Image
import seaborn as sns
import pandas as pd

# %%
a = np.random.randn(3,3)
b = np.random.randn(3,2)

# %%
a
# Out:
# array([[-0.27631306,  0.14065261, -0.56156956],
#        [-1.51485751,  0.26376859, -0.01597145],
#        [-0.72360329, -0.26604065, -0.11167878]])

# %%
b
# Out:
# array([[ 0.08254382, -0.2399628 ],
#        [-1.76004183, -1.25898514],
#        [ 0.78640355, -0.18171088]])

# %%
a@b
# Out:
# array([[-0.7119827 , -0.00873139],
#        [-0.6018459 ,  0.0343309 ],
#        [ 0.32068909,  0.52887234]])

# %%
np.dot(a,b)
# Out:
# array([[-0.7119827 , -0.00873139],
#        [-0.6018459 ,  0.0343309 ],
#        [ 0.32068909,  0.52887234]])

# %% [markdown]
# # conclusion:
#
# * matrix multiplication and dot products are same.

# %% [markdown]
# # day 74

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('mouse_viral_study.csv')
df.head(5)
# Out:
#    Med_1_mL  Med_2_mL  Virus Present
# 0  6.508231  8.582531              0
# 1  4.126116  3.073459              1
# 2  6.427870  6.369758              0
# 3  3.672953  4.905215              1
# 4  1.580321  2.440562              1

# %%
sns.scatterplot(data= df,x='Med_1_mL', y='Med_2_mL',hue='Virus Present')

m = -1
b = 11
x = np.linspace(0,10,100)
y = m*x + b

plt.plot(x,y,color='black')



plt.show()

# %% [markdown]
# # conclusion:
#
# * what support vector machine does is here we had to put our slope value (m) and intercept value(b) manually but we may not know exactly the slope and intercept for the hyperplane(the center line) always.
#
# * support vector machine automatically optimizes to get us the right slope, intercept and the line. its mathematical properties make it do it effortlessly.

# %% [markdown]
# # model_building

# %%
X = df.drop('Virus Present',axis=1)

y = df['Virus Present']

# from support vector machine family we are importing support vector classifier. 
from sklearn.svm import SVC


model = SVC(kernel='linear', C=1000)


model.fit(X,y)

# this is a self-made python program that is available in the directory. check it out!
from svm_margin_plot import plot_svm_boundary

plot_svm_boundary(model,X,y)
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # conclusion
#
# # C value
# * C is a regularization parameter. it penalises the model for misclassification. larger the C value, smaller the margin and fewer misclassification, if the c value is small, it makes bigger margin and propensity for a lot of misclassifications rises with it.  i.e C=1000 might penalise the model very severely for misclassification than C=1 but larger C value means a smaller margin around the hyper-plane. so there is a trade-off between the size of the margin and penalty for misclassification.
#
# # why a smaller C value or a larger C value?
#
# * C value defines how larger should the boundary between different classes of datapoint look.
#
# * larger boundary is beneficial being able to classify unseen data well. that means the classification performance on the test data will see a great improvement as compared to having a smaller boundary.
#
# * the battle between a larger C value or a smaller C value is actually a battle between accuracy in predicability and accuracy in classification so the ideal C value that balances both of these aspects would be preferred.
#
# * simple definition: smaller c allows a lot of misclassified points, larger c allows less of misclassified points

# %%
help(SVC)
# Out:
# Help on class SVC in module sklearn.svm._classes:
#
# class SVC(sklearn.svm._base.BaseSVC)
#  |  SVC(*, C=1.0, kernel='rbf', degree=3, gamma='scale', coef0=0.0, shrinking=True, probability=False, tol=0.001, cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape='ovr', break_ties=False, random_state=None)
#  |
#  |  C-Support Vector Classification.
#  |
#  |  The implementation is based on libsvm. The fit time scales at least
#  |  quadratically with the number of samples and may be impractical
#  |  beyond tens of thousands of samples. For large datasets
#  |  consider using :class:`~sklearn.svm.LinearSVC` or
#  |  :class:`~sklearn.linear_model.SGDClassifier` instead, possibly after a
#  |  :class:`~sklearn.kernel_approximation.Nystroem` transformer.
#  |
#  |  The multiclass support is handled according to a one-vs-one scheme.
#  |
#  |  For details on the precise mathematical formulation of the provided
# ...

# %% [markdown]
# # part 2

# %%
model = SVC(kernel='rbf',C=1)
model.fit(X,y)
plot_svm_boundary(model,X,y)
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Gamma value:
#
# * Boundary definition happens with Gamma. overfitting and underfitting. giving all wriggly ameobic shapes to the boundaries of the classified subjects larger the gamma value is.
# * so we have to have a ideal gamma value not exceeding the needful threshold.

# %%
model = SVC(kernel='rbf',C=1,gamma='auto')  
model.fit(X,y)
plot_svm_boundary(model,X,y)
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
model = SVC(kernel='rbf',C=1,gamma=1)
model.fit(X,y)
plot_svm_boundary(model,X,y)
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
model = SVC(kernel='rbf',C=1,gamma=10)
model.fit(X,y)
plot_svm_boundary(model,X,y)
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # kernel sigmoid

# %%
model = SVC(kernel='sigmoid')
model.fit(X,y)
plot_svm_boundary(model,X,y)

# all the data
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
model = SVC(kernel='poly',C=1,degree=2)
model.fit(X,y)
plot_svm_boundary(model,X,y)
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # grid search to find the ideal kernel and C value and Gamma value

# %%
from sklearn.model_selection import GridSearchCV

svm = SVC()
param_grid ={'kernel':['linear','rbf','sigmoid'],'C':[0.01,0.1,1,10],'gamma':['auto',1,2,10]}

grid_model = GridSearchCV(svm,param_grid)

grid_model.fit(X,y)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.01, 0.1, 1, 10], 'gamma': ['auto', 1, 2, 10],
#                          'kernel': ['linear', 'rbf', 'sigmoid']})

# %%
grid_model.best_params_
# Out:
# {'C': 0.01, 'gamma': 'auto', 'kernel': 'linear'}

# %% [markdown]
# # cement slump

# %%
df = pd.read_csv('cement_slump.csv')
df.head(5)
# Out:
#    Cement   Slag  Fly ash  Water    SP  Coarse Aggr.  Fine Aggr.  SLUMP(cm)  \
# 0   273.0   82.0    105.0  210.0   9.0         904.0       680.0       23.0
# 1   163.0  149.0    191.0  180.0  12.0         843.0       746.0        0.0
# 2   162.0  148.0    191.0  179.0  16.0         840.0       743.0        1.0
# 3   162.0  148.0    190.0  179.0  19.0         838.0       741.0        3.0
# 4   154.0  112.0    144.0  220.0  10.0         923.0       658.0       20.0
#
#    FLOW(cm)  Compressive Strength (28-day)(Mpa)
# 0      62.0                               34.99
# 1      20.0                               41.14
# 2      20.0                               41.81
# 3      21.5                               42.08
# 4      64.0                               26.82

# %%
plt.figure(figsize=(12,6))
sns.heatmap(data=df.corr(),annot=True)

plt.show()

# %% [markdown]
# # model_building.

# %%
x = df.drop('Compressive Strength (28-day)(Mpa)',axis=1)
y = df['Compressive Strength (28-day)(Mpa)']

# train test split
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=101)

# scaling the model
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(x_train)
scaled_x_train = scaler.transform(x_train)
scaled_x_test = scaler.transform(x_test)

# support vector machine model (base_model with default values without ideal values optimisation)
from sklearn.svm import SVR

base_model = SVR()
base_model.fit(scaled_x_train,y_train)

prediction = base_model.predict(scaled_x_test)
actual = y_test

from sklearn.metrics import mean_absolute_error,mean_squared_error

mae = mean_absolute_error(actual,prediction)
rmse = np.sqrt(mean_squared_error(actual,prediction))

# %%
mae
# Out:
# 5.236902091259179

# %%
rmse
# Out:
# 6.695914838327133

# %%
y_test.mean() # this is mean. rmse and mae are standard deviations to give you context.
# Out:
# 36.26870967741935

# %% [markdown]
# # grid search model with ideal optimised values.

# %%
from sklearn.model_selection import GridSearchCV


param_grid = {'kernel':['linear','rbf','sigmoid','poly'],'C':[0.01,0.1,0.5,1,10],
              'gamma':['auto','scale',0.8,1,2],'degree':[2,3,4],'epsilon':[0,0.01,0.1,0.2,0.5,1,2]}

model = SVR()
grid_model = GridSearchCV(model,param_grid)
grid_model.fit(scaled_x_train,y_train)
prediction = grid_model.predict(scaled_x_test)

actual = y_test

mae = mean_absolute_error(actual,prediction)
rmse = np.sqrt(mean_squared_error(actual,prediction))

# %%
grid_model.get_params
# Out:
# <bound method BaseEstimator.get_params of GridSearchCV(estimator=SVR(),
#              param_grid={'C': [0.01, 0.1, 0.5, 1, 10], 'degree': [2, 3, 4],
#                          'epsilon': [0, 0.01, 0.1, 0.2, 0.5, 1, 2],
#                          'gamma': ['auto', 'scale', 0.8, 1, 2],
#                          'kernel': ['linear', 'rbf', 'sigmoid', 'poly']})>

# %%
grid_model.best_params_
# Out:
# {'C': 10, 'degree': 2, 'epsilon': 0, 'gamma': 'auto', 'kernel': 'rbf'}

# %%
mae
# Out:
# 2.3642823775495607

# %%
rmse
# Out:
# 3.487432014624356
