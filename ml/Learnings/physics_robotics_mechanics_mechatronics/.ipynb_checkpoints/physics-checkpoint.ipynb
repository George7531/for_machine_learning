# %% [markdown]
# # day 402

# %% [markdown]
# # Basic Trig:
#
# $ \sin(\theta)= \cos(90-\theta) $
#
#
# ## link to understand cofunctions, right angled triangle and etc
# [click me 🌺🌻🌼](https://www.khanacademy.org/science/in-in-class11th-physics/in-in-class11th-physics-basic-math-concepts-for-physics-prerequisite/in-in-class11th-physics-basic-math-concepts-for-physics-prerequisite-basics-of-trigonometry/a/sine-and-cosine-are-cofunctions)
#
#
# ## link to understand special triangles:
# [click me 🍑🍑🍑](https://www.khanacademy.org/science/in-in-class11th-physics/in-in-class11th-physics-basic-math-concepts-for-physics-prerequisite/in-in-class11th-physics-basic-math-concepts-for-physics-prerequisite-basics-of-trigonometry/a/trig-ratios-of-special-triangles)
#
# ## quick recap:
# ![fsdf](https://cdn.britannica.com/97/69697-050-BADA0D81/definitions-relationships-functions-sin-cos-example-A.jpg)
# ![fsfs](https://qph.cf2.quoracdn.net/main-qimg-24d8d43b2f2bd12f7c39f2b9b6d4d8a8-lq)
#
#
# ## unit circle:
# ![image.png](attachment:image.png)
#
# ## graph the sinusoidal function in a graph by comparing it with unit circles:
# ![sfsd](images/110724_physics.png)
#
# # link to watch video:
# https://www.youtube.com/watch?v=sjUhr0HkLUg

# %% [markdown]
# # visualizing the tangent line

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-2*np.pi,2*np.pi,1000)
y = np.tan(x)

plt.plot(x,y)

plt.xlabel('x')
plt.ylabel('y')
plt.show()
